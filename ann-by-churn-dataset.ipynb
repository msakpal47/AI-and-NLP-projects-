# %%
import tensorflow as tf 
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
pd.read_csv('/kaggle/input/ann-ai/Churn_Modelling.csv')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
churn = pd.read_csv('/kaggle/input/ann-ai/Churn_Modelling.csv')

# %%
churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
churn.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
churn.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# count   10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# unique           NaN           NaN            NaN            NaN          NaN
# top              NaN           NaN            NaN            NaN          NaN
# freq             NaN           NaN            NaN            NaN          NaN
# mean       38.921800      5.012800   76485.889288       1.530200      0.70550
# std        10.487806      2.892174   62397.405202       0.581654      0.45584
# min        18.000000      0.000000       0.000000       1.000000      0.00000
# 25%        32.000000      3.000000       0.000000       1.000000      0.00000
# 50%        37.000000      5.000000   97198.540000       1.000000      1.00000
# 75%        44.000000      7.000000  127644.240000       2.000000      1.00000
# max        92.000000     10.000000  250898.090000       4.000000      1.00000
#
#         IsActiveMember  EstimatedSalary        Exited
# count     10000.000000     10000.000000  10000.000000
# unique             NaN              NaN           NaN
# top                NaN              NaN           NaN
# freq               NaN              NaN           NaN
# mean          0.515100    100090.239881      0.203700
# std           0.499797     57510.492818      0.402769
# min           0.000000        11.580000      0.000000
# 25%           0.000000     51002.110000      0.000000
# 50%           1.000000    100193.915000      0.000000
# 75%           1.000000    149388.247500      0.000000
# max           1.000000    199992.480000      1.000000

# %%
churn.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
churn.shape
# Out:
# (10000, 14)

# %%
churn.size
# Out:
# 140000

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
churn.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
churn1= churn.drop(['RowNumber', 'CustomerId', 'Surname'],axis=1)
churn1.head(7)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
# 5          645     Spain    Male   44       8  113755.78              2
# 6          822    France    Male   50       7       0.00              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0
# 5          1               0        149756.71       1
# 6          1               1         10062.80       0

# %%
from sklearn.preprocessing import LabelEncoder

# Create an instance of LabelEncoder
le = LabelEncoder()

# Apply fit_transform to the 'Geography' and 'Gender' columns
churn1['Geography'] = le.fit_transform(churn1['Geography'])
churn1['Gender'] = le.fit_transform(churn1['Gender'])

# %%
churn1.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
## checking for null value / if nullpresent fill it / IQR / Corrlation matrix

# %%
X= churn1[['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance','NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']]
y= churn1['Exited']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
X_train = sc.fit_transform(X_train)

# %%
X_test = sc.transform(X_test)

# %%
X_train = np.asanyarray(X_train)
y_train = np.asanyarray(y_train)
X_test = np.asanyarray(X_test)
y_train = np.asanyarray(y_train)

# %%
X_train.shape
# Out:
# (8000, 10)

# %%
y_train.shape
# Out:
# (8000,)

# %% [markdown]
# ## we are building the  model of ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten,Activation

# %%
from tensorflow.keras.layers import Conv2D,MaxPool2D,GlobalAveragePooling2D,ZeroPadding2D,BatchNormalization

# %%
from tensorflow.keras.layers import ReLU

# %%
Classifier = Sequential ()

# %%
Classifier.add(Dense(70, input_shape=(10,),activation='relu'))
Classifier.add(Dropout(0.25))
Classifier.add(Dense(50, activation='relu'))
Classifier.add(Dropout(0.25))
Classifier.add(Dense(40,activation='relu'))
Classifier.add(Dropout(0.25))
Classifier.add(Dense(30,activation='relu'))
Classifier.add(Dropout(0.25))
Classifier.add(Dense(20, activation='relu'))
Classifier.add(Dropout(0.25))
Classifier.add(Dense(10,activation='relu'))
Classifier.add(Dropout(0.25))
Classifier.add(Dense(5,activation='relu'))
Classifier.add(Dropout(0.25))
Classifier.add(Dense(1,activation='sigmoid'))
Classifier.add(Dropout(0.25))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
Classifier.add(Dense(1, activation='sigmoid'))

# %%
Classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Classifier.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#model_history=Classifier.fit(X_train, y_train, batch_size=32, epochs=50,validation_split=0.33)
# Out:
# Epoch 1/50
# 155/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6762 - loss: 0.6834
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 model_history=Classifier.fit(X_train, y_train, batch_size=32, epochs=50,validation_split=0.33)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/losses/loss.py:90, in squeeze_or_expand_to_same_rank(x1, x2, expand_rank_1)
#      88 def squeeze_or_expand_to_same_rank(x1, x2, expand_rank_1=True):
#      89     """Squeeze/expand last dim if ranks differ from expected by exactly 1."""
# ---> 90     x1_rank = len(x1.shape)
#      91     x2_rank = len(x2.shape)
#      92     if x1_rank == x2_rank:
#
# ValueError: Cannot take the length of shape with unknown rank.

# %%
model_history=Classifier.fit(X_train, y_train, batch_size=55, epochs=77,validation_split=0.33)
# Out:
# Epoch 1/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3570 - loss: 1.6148 - val_accuracy: 0.8016 - val_loss: 0.6392
# Epoch 2/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4500 - loss: 1.4024 - val_accuracy: 0.8016 - val_loss: 0.4958
# Epoch 3/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6591 - loss: 1.2293 - val_accuracy: 0.8016 - val_loss: 0.4598
# Epoch 4/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6518 - loss: 1.3161 - val_accuracy: 0.8016 - val_loss: 0.4401
# Epoch 5/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6682 - loss: 1.3222 - val_accuracy: 0.8016 - val_loss: 0.4429
# Epoch 6/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6825 - loss: 1.1608 - val_accuracy: 0.8016 - val_loss: 0.4333
# Epoch 7/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6811 - loss: 1.1984 - val_accuracy: 0.8016 - val_loss: 0.4384
# Epoch 8/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6840 - loss: 1.2011 - val_accuracy: 0.8016 - val_loss: 0.4237
# Epoch 9/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6887 - loss: 1.3294 - val_accuracy: 0.8016 - val_loss: 0.4186
# Epoch 10/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6849 - loss: 1.2552 - val_accuracy: 0.8023 - val_loss: 0.4207
# Epoch 11/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7049 - loss: 1.1061 - val_accuracy: 0.8023 - val_loss: 0.4211
# Epoch 12/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7933 - loss: 1.2114 - val_accuracy: 0.8148 - val_loss: 0.4057
# Epoch 13/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8026 - loss: 1.2106 - val_accuracy: 0.8167 - val_loss: 0.3966
# Epoch 14/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8193 - loss: 1.0581 - val_accuracy: 0.8141 - val_loss: 0.4046
# Epoch 15/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8246 - loss: 1.1592 - val_accuracy: 0.8220 - val_loss: 0.3958
# Epoch 16/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8116 - loss: 1.1893 - val_accuracy: 0.8232 - val_loss: 0.3885
# Epoch 17/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8237 - loss: 1.1565 - val_accuracy: 0.8307 - val_loss: 0.3775
# Epoch 18/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8242 - loss: 1.1818 - val_accuracy: 0.8247 - val_loss: 0.3818
# Epoch 54/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8204 - loss: 1.1834 - val_accuracy: 0.8262 - val_loss: 0.3827
# Epoch 55/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8172 - loss: 1.2102 - val_accuracy: 0.8262 - val_loss: 0.3859
# Epoch 56/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8181 - loss: 1.1121 - val_accuracy: 0.8315 - val_loss: 0.3804
# Epoch 57/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8277 - loss: 1.1183 - val_accuracy: 0.8307 - val_loss: 0.3815
# Epoch 58/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8164 - loss: 1.2137 - val_accuracy: 0.8345 - val_loss: 0.3764
# Epoch 59/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8285 - loss: 1.1151 - val_accuracy: 0.8342 - val_loss: 0.3789
# Epoch 60/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8237 - loss: 1.2095 - val_accuracy: 0.8334 - val_loss: 0.3761
# Epoch 61/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8267 - loss: 1.1461 - val_accuracy: 0.8379 - val_loss: 0.3730
# Epoch 62/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8242 - loss: 1.2273 - val_accuracy: 0.8372 - val_loss: 0.3746
# Epoch 63/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8340 - loss: 1.2209 - val_accuracy: 0.8364 - val_loss: 0.3742
# Epoch 64/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8207 - loss: 1.1498 - val_accuracy: 0.8262 - val_loss: 0.3913
# Epoch 65/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8152 - loss: 1.0717 - val_accuracy: 0.8258 - val_loss: 0.3851
# Epoch 66/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8167 - loss: 1.1266 - val_accuracy: 0.8266 - val_loss: 0.3817
# Epoch 67/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8212 - loss: 1.0303 - val_accuracy: 0.8289 - val_loss: 0.3782
# Epoch 68/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8311 - loss: 1.0889 - val_accuracy: 0.8258 - val_loss: 0.3823
# Epoch 69/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8332 - loss: 1.0380 - val_accuracy: 0.8266 - val_loss: 0.3756
# Epoch 70/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8279 - loss: 1.1493 - val_accuracy: 0.8334 - val_loss: 0.3726
# Epoch 71/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8281 - loss: 1.1601 - val_accuracy: 0.8330 - val_loss: 0.3756
# Epoch 72/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8329 - loss: 1.0636 - val_accuracy: 0.8254 - val_loss: 0.3890
# Epoch 73/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8223 - loss: 1.1257 - val_accuracy: 0.8277 - val_loss: 0.3823
# Epoch 74/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8222 - loss: 1.1022 - val_accuracy: 0.8292 - val_loss: 0.3795
# Epoch 75/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8245 - loss: 1.1846 - val_accuracy: 0.8330 - val_loss: 0.3766
# Epoch 76/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8254 - loss: 1.0424 - val_accuracy: 0.8300 - val_loss: 0.3756
# Epoch 77/77
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8322 - loss: 1.0916 - val_accuracy: 0.8349 - val_loss: 0.3721

# %%
Classifier.evaluate(X_test, y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2065 - loss: 0.6960
# [0.6958515048027039, 0.20350000262260437]

# %%
Classifier.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[0.49332625],
#        [0.460739  ],
#        [0.52349365],
#        ...,
#        [0.46241376],
#        [0.46064863],
#        [0.46066236]], dtype=float32)

# %%
y_predict=Classifier.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
Classifier.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 70)             │           770 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 70)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 50)             │         3,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 40)             │         2,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 40)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 30)             │         1,230 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 5)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,451 (99.42 KB)
#  Trainable params: 8,483 (33.14 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 16,968 (66.29 KB)

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
pred_y = Classifier.predict(X_test)
y_pred = (pred_y > 0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import classification_report
score=classification_report(y_test,y_pred)
print(score)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1593
#            1       0.80      0.41      0.54       407
#
#     accuracy                           0.86      2000
#    macro avg       0.83      0.69      0.73      2000
# weighted avg       0.85      0.86      0.84      2000
