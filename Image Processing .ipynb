# %%
#pip install opencv-python
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.8 MB 4.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.8/38.8 MB 4.2 MB/s eta 0:00:09
#    -- ------------------------------------- 2.1/38.8 MB 4.2 MB/s eta 0:00:09
#    -- ------------------------------------- 2.4/38.8 MB 3.3 MB/s eta 0:00:12
#    -- ------------------------------------- 2.9/38.8 MB 2.8 MB/s eta 0:00:14
#    --- ------------------------------------ 3.4/38.8 MB 2.7 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.2/38.8 MB 2.8 MB/s eta 0:00:13
#    ----- ---------------------------------- 5.0/38.8 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.8/38.8 MB 3.0 MB/s eta 0:00:12
#    ------ --------------------------------- 6.6/38.8 MB 3.1 MB/s eta 0:00:11
#    ------- -------------------------------- 7.6/38.8 MB 3.2 MB/s eta 0:00:10
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Define the scale factor
    scale_factor_1 = 3.0  
    scale_factor_2 = 1/3.0

    # Get the original image dimensions
    height, width = image_rgb.shape[:2]

    # Calculate the new image dimensions
    new_height = int(height * scale_factor_1)
    new_width = int(width * scale_factor_1)

    # Resize the image
    zoomed_image = cv2.resize(src=image_rgb, 
                              dsize=(new_width, new_height), 
                              interpolation=cv2.INTER_CUBIC)

    new_height1 = int(height * scale_factor_2)
    new_width1 = int(width * scale_factor_2)

    # Scaled image
    scaled_image = cv2.resize(src=image_rgb, 
                              dsize=(new_width1, new_height1), 
                              interpolation=cv2.INTER_AREA)

    # Create subplots
    fig, axs = plt.subplots(1, 3, figsize=(10, 4))

    # Plot the original image
    axs[0].imshow(image_rgb)
    axs[0].set_title('Original Image Shape:'+str(image_rgb.shape))

    # Plot the Zoomed Image
    axs[1].imshow(zoomed_image)
    axs[1].set_title('Zoomed Image Shape:'+str(zoomed_image.shape))

    # Plot the Scaled Image
    axs[2].imshow(scaled_image)
    axs[2].set_title('Scaled Image Shape:'+str(scaled_image.shape))

    # Remove ticks from the subplots
    for ax in axs:
        ax.set_xticks([])
        ax.set_yticks([])

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %%
##Here's the code for image rotation###

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get the image dimensions
    (h, w) = image_rgb.shape[:2]
    
    # Define the center of the image
    center = (w // 2, h // 2)
    
    # Define the rotation angle and scale
    angle = 45  # Angle of rotation
    scale = 1.0  # Scale factor

    # Create the rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, scale)

    # Rotate the image
    rotated_image = cv2.warpAffine(image_rgb, M, (w, h))

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(image_rgb)
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the rotated image
    axs[1].imshow(rotated_image)
    axs[1].set_title('Rotated Image')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##Here's the code for image translation:

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get the image dimensions
    (h, w) = image_rgb.shape[:2]

    # Define the translation matrix
    tx, ty = 50, 30  # Translation in x and y direction
    M = np.float32([[1, 0, tx], [0, 1, ty]])

    # Translate the image
    translated_image = cv2.warpAffine(image_rgb, M, (w, h))

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(image_rgb)
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the translated image
    axs[1].imshow(translated_image)
    axs[1].set_title('Translated Image')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %%
##Here’s how you can normalize an image using OpenCV and NumPy##

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Normalize the image to range [0, 1]
    image_normalized = image_rgb / 255.0

    # Optionally, if you want to normalize to range [0, 255] and convert to uint8
    image_normalized_uint8 = (image_normalized * 255).astype(np.uint8)

    # Create subplots
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))

    # Plot the original image
    axs[0].imshow(image_rgb)
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the normalized image [0, 1]
    axs[1].imshow(image_normalized)
    axs[1].set_title('Normalized Image [0, 1]')
    axs[1].axis('off')

    # Plot the normalized image [0, 255] (optional)
    axs[2].imshow(image_normalized_uint8)
    axs[2].set_title('Normalized Image [0, 255]')
    axs[2].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##Edge Detection Code Using Canny Edge Detector

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Convert BGR image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply GaussianBlur to reduce noise and improve edge detection
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

    # Perform Canny edge detection
    edges = cv2.Canny(blurred_image, 100, 200)

    # Create subplots
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))

    # Plot the original image
    axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the grayscale image
    axs[1].imshow(gray_image, cmap='gray')
    axs[1].set_title('Grayscale Image')
    axs[1].axis('off')

    # Plot the edges detected
    axs[2].imshow(edges, cmap='gray')
    axs[2].set_title('Edges Detected')
    axs[2].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ###Code for Different Blurring Techniques

# %%
###1. Gaussian Blur

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Apply Gaussian Blur
    gaussian_blur = cv2.GaussianBlur(image, (15, 15), 0)

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the Gaussian blurred image
    axs[1].imshow(cv2.cvtColor(gaussian_blur, cv2.COLOR_BGR2RGB))
    axs[1].set_title('Gaussian Blur')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %%
##2. Average Blur

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Apply Average Blur
    average_blur = cv2.blur(image, (15, 15))

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the Average blurred image
    axs[1].imshow(cv2.cvtColor(average_blur, cv2.COLOR_BGR2RGB))
    axs[1].set_title('Average Blur')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %%
###3. Median Blur

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image with raw string
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg')

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Apply Median Blur
    median_blur = cv2.medianBlur(image, 15)

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the Median blurred image
    axs[1].imshow(cv2.cvtColor(median_blur, cv2.COLOR_BGR2RGB))
    axs[1].set_title('Median Blur')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##Morphological image processing is a technique for extracting image components that are useful in the representation and description of region shapes. OpenCV provides several morphological operations such as erosion, dilation, opening, and closing.

# %%
##Erosion

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg', cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Define the kernel for erosion
    kernel = np.ones((5, 5), np.uint8)

    # Apply erosion
    eroded_image = cv2.erode(image, kernel, iterations=1)

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(image, cmap='gray')
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the eroded image
    axs[1].imshow(eroded_image, cmap='gray')
    axs[1].set_title('Eroded Image')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %%
###Dilation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg', cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Define the kernel for dilation
    kernel = np.ones((5, 5), np.uint8)

    # Apply dilation
    dilated_image = cv2.dilate(image, kernel, iterations=1)

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(image, cmap='gray')
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the dilated image
    axs[1].imshow(dilated_image, cmap='gray')
    axs[1].set_title('Dilated Image')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %%
###Opening

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg', cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Define the kernel for opening
    kernel = np.ones((5, 5), np.uint8)

    # Apply opening
    opened_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(image, cmap='gray')
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the opened image
    axs[1].imshow(opened_image, cmap='gray')
    axs[1].set_title('Opened Image')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()

# %%
##Closing

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread(r'C:\Users\C-Dot\Desktop\onkar sir\nlp and AI\classic_volvo.jpg', cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found or cannot be opened.")
else:
    # Define the kernel for closing
    kernel = np.ones((5, 5), np.uint8)

    # Apply closing
    closed_image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plot the original image
    axs[0].imshow(image, cmap='gray')
    axs[0].set_title('Original Image')
    axs[0].axis('off')

    # Plot the closed image
    axs[1].imshow(closed_image, cmap='gray')
    axs[1].set_title('Closed Image')
    axs[1].axis('off')

    # Display the subplots
    plt.tight_layout()
    plt.show()
